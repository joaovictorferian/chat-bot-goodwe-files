# %%
# !git clone https://github.com/joaovictorferian/chat-bot-goodwe-files.git
# Out:
# Cloning into 'chat-bot-goodwe-files'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 58 (delta 12), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 30.85 MiB | 11.45 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# !git -C /content/chat-bot-goodwe-files pull #Rodar apenas se novos arquivos foram adicionados no repositório
# Out:
# Already up to date.

# %%
# !pip install -q \
    langchain==0.1.20 \
    langchain-openai==0.1.6 \
    langchain-community==0.0.38 \
    langchain-text-splitters \
    faiss-cpu \
    pypdf \
    tiktoken \
    ipywidgets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 66.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.1/303.1 kB 22.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 22.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 71.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.1.53 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# wheel 0.47.0 requires packaging>=24.0, but you have packaging 23.2 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray 2025.12.0 requires packaging>=24.1, but you have packaging 23.2 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# bigquery-magics 0.14.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# db-dtypes 1.7.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.1.53 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.29.0 requires tenacity<10.0.0,>=9.0.0, but you have tenacity 8.5.0 which is incompatible.
# google-cloud-bigquery 3.41.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# langgraph-checkpoint 4.1.1 requires langchain-core>=0.2.38, but you have langchain-core 0.1.53 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# langgraph 1.2.4 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.1.53 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
import os
from google.colab import userdata

# %%
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

DOCS_DIR   = '/content/chat-bot-goodwe-files/goodwe_docs'

os.makedirs(DOCS_DIR, exist_ok=True)

# %%
import glob
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
pdf_paths = glob.glob(os.path.join(DOCS_DIR, '**/*.pdf'), recursive=True)

if not pdf_paths:
    print('Nenhum PDF encontrado em', DOCS_DIR)
    print('   Adicione os manuais GoodWe na pasta e rode novamente.')
else:
    print(f'{len(pdf_paths)} PDF(s) encontrado(s):')
    for p in pdf_paths:
        print(f'   • {os.path.basename(p)}')

    all_docs = []
    for path in pdf_paths:
        loader = PyPDFLoader(path)
        docs = loader.load()
        for doc in docs:
            doc.metadata['source_file'] = os.path.basename(path)
        all_docs.extend(docs)
        print(f'{os.path.basename(path)} — {len(docs)} páginas')

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=200,
        separators=['\n\n', '\n', '. ', ' ', '']
    )
    chunks = splitter.split_documents(all_docs)
    print(f'\n{len(chunks)} chunks gerados a partir de {len(all_docs)} páginas')
# Out:
# 10 PDF(s) encontrado(s):
#    • 1CC - EV CHALLENGE GOODWE+FIAP 2026.pdf
#    • Goodwe HCA Series Quick Installation Manual 2.pdf
#    • Goodwe Hca Series User Manual.pdf
#    • GW_HCA Series_User Manual-EN.pdf
#    • Apresentação Challenge FIAP4+GoodWe 2026.pdf
#    • GW_HCA-G2_Datasheet-EN.pdf
#    • GW_SEMS Portal APP_User Manual-EN.pdf
#    • GW_ESS Troubleshooting Guide-EMEA_EN.pdf
#    • FIAP_EV Challenge_2026_Mentoria1.pdf
#    • Goodwe HCA Series Quick Installation Manual.pdf
# 1CC - EV CHALLENGE GOODWE+FIAP 2026.pdf — 14 páginas
# Goodwe HCA Series Quick Installation Manual 2.pdf — 31 páginas
# Goodwe Hca Series User Manual.pdf — 68 páginas
# GW_HCA Series_User Manual-EN.pdf — 46 páginas
# Apresentação Challenge FIAP4+GoodWe 2026.pdf — 23 páginas
# GW_HCA-G2_Datasheet-EN.pdf — 2 páginas
# GW_SEMS Portal APP_User Manual-EN.pdf — 33 páginas
# GW_ESS Troubleshooting Guide-EMEA_EN.pdf — 37 páginas
# FIAP_EV Challenge_2026_Mentoria1.pdf — 11 páginas
# Goodwe HCA Series Quick Installation Manual.pdf — 31 páginas
#
# 432 chunks gerados a partir de 296 páginas

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS

# %%
embeddings = OpenAIEmbeddings(model='text-embedding-3-small')

print('Gerando embeddings...')

vectorstore = FAISS.from_documents(chunks, embeddings)

print(f'FAISS gerado — {vectorstore.index.ntotal} vetores')
# Out:
# Gerando embeddings...
# FAISS gerado — 432 vetores

# %%
from langchain_openai import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferWindowMemory
from langchain.prompts import PromptTemplate

# %%
SYSTEM_PROMPT = """Você é um assistente técnico especializado em equipamentos de recarga
veicular da GoodWe. Você auxilia técnicos de campo na instalação, configuração,
diagnóstico de falhas e manutenção dos eletropostos HCA Series.

Regras:
- Responda com base no contexto fornecido abaixo.
- Mesmo que a informação seja parcial, responda com o que tiver disponível.
- Seja objetivo e técnico.
- Quando relevante, cite o documento de onde veio a informação.
- Responda em português brasileiro.
- Só diga que não encontrou a informação se o contexto realmente não contiver
  nada relacionado à pergunta.

Contexto:
{context}

Histórico:
{chat_history}

Pergunta: {question}
Resposta:"""

prompt = PromptTemplate(
    input_variables=['context', 'chat_history', 'question'],
    template=SYSTEM_PROMPT
)

llm = ChatOpenAI(
    model_name='gpt-4o-mini',
    temperature=0.1,
    max_tokens=1000
)

memory = ConversationBufferWindowMemory(
    k=5,
    memory_key='chat_history',
    return_messages=True,
    output_key='answer'
)

retriever = vectorstore.as_retriever(
    search_type='similarity',
    search_kwargs={'k': 4}
)

chain = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=retriever,
    memory=memory,
    combine_docs_chain_kwargs={'prompt': prompt},
    return_source_documents=True,
    verbose=False
)

print('Chain configurada e pronta')
# Out:
# Chain configurada e pronta

# %%
TEST_QUESTIONS = [
    "The Led Charger is flashing green. What does that mean?",
    "What are the charging modes avaiable in the HCA series chargers?",
    "How to install the HCA Charger on the wall? What are the steps?",
    "How to configure the RFID card authentication on the HCA?",
    "How to connect the charger to the SolarGo app for the first time?"
]

print('=' * 70)
print('MODELO DE TESTE — SPRINT 1')
print('Chatbot GoodWe | Persona: Técnico de Campo')
print('=' * 70)

memory.clear()

results = []

for i, question in enumerate(TEST_QUESTIONS, 1):
    print(f'\n[PERGUNTA {i}]')
    print(f'>>> {question}')
    print()

    response = chain.invoke({'question': question})
    answer   = response['answer']
    sources  = response.get('source_documents', [])

    print(f'[RESPOSTA]')
    print(answer)

    if sources:
        print(f'\n[FONTES RECUPERADAS]')
        seen = set()
        for doc in sources:
            src = doc.metadata.get('source_file', 'desconhecido')
            page = doc.metadata.get('page', '?')
            key = f'{src} p.{page}'
            if key not in seen:
                print(f'   • {key}')
                seen.add(key)

    print('-' * 70)

    results.append({
        'pergunta': question,
        'resposta': answer,
        'fontes': [f"{d.metadata.get('source_file')} p.{d.metadata.get('page')}" for d in sources]
    })

    memory.clear()
# Out:
# ======================================================================
# MODELO DE TESTE — SPRINT 1
# Chatbot GoodWe | Persona: Técnico de Campo
# ======================================================================
#
# [PERGUNTA 1]
# >>> The Led Charger is flashing green. What does that mean?
#
# [RESPOSTA]
# Quando o LED do carregador está piscando em verde, isso significa que o sistema do carregador está em processo de atualização. (Fonte: User Manual V1.3-2024-07-24, seção 3.6.3)
#
# [FONTES RECUPERADAS]
#    • GW_HCA Series_User Manual-EN.pdf p.20
#    • GW_HCA Series_User Manual-EN.pdf p.38
#    • Goodwe Hca Series User Manual.pdf p.23
#    • Goodwe Hca Series User Manual.pdf p.42
# ----------------------------------------------------------------------
#
# [PERGUNTA 2]
# >>> What are the charging modes avaiable in the HCA series chargers?
#
# [RESPOSTA]
# Os modos de carregamento disponíveis nos carregadores da série HCA são:
#
# 1. **Fast** (Rápido)
# 2. **PV priority** (Prioridade para energia solar)
# 3. **PV+battery** (Energia solar + bateria)
#
# Esses modos permitem que o carregador utilize eletricidade da rede elétrica, de painéis solares (PV) ou de baterias para carregar veículos elétricos. (Fonte: User Manual V1.1-2024-10-12, seção 8.3.5)
#
# [FONTES RECUPERADAS]
#    • GW_HCA Series_User Manual-EN.pdf p.0
#    • Goodwe Hca Series User Manual.pdf p.4
#    • Goodwe Hca Series User Manual.pdf p.13
#    • Goodwe Hca Series User Manual.pdf p.54
# ----------------------------------------------------------------------
#
# [PERGUNTA 3]
# >>> How to install the HCA Charger on the wall? What are the steps?
#
# [RESPOSTA]
# Para instalar o carregador HCA na parede, siga os seguintes passos:
#
# 1. Retire a placa de montagem do carregador.
# 2. Coloque a placa de montagem na parede horizontalmente e marque as posições para a perfuração dos furos.
# 3. Perfure os furos utilizando uma furadeira de impacto, com profundidade de 50 mm e diâmetro de 8 mm.
# 4. Use os parafusos de expansão para fixar a placa de montagem na parede.
# 5. Instale o carregador na placa de montagem.
# 6. Aperte as porcas para garantir que a placa de montagem e o carregador estejam firmemente instalados, assegurando a confiabilidade da instalação.
#
# Essas instruções são baseadas no manual do usuário V1.3-2024-07-24, seção 5.2.2.
#
# [FONTES RECUPERADAS]
#    • Goodwe Hca Series User Manual.pdf p.29
#    • Goodwe Hca Series User Manual.pdf p.6
#    • GW_HCA Series_User Manual-EN.pdf p.26
#    • Goodwe HCA Series Quick Installation Manual 2.pdf p.1
# ----------------------------------------------------------------------
#
# [PERGUNTA 4]
# >>> How to configure the RFID card authentication on the HCA?
#
# [RESPOSTA]
# Para configurar a autenticação do cartão RFID na linha HCA G2, siga os passos abaixo:
#
# 1. **Cadastro de Cartões**: Utilize a plataforma de monitoramento para cadastrar os cartões RFID. A linha HCA G2 suporta até 10 cartões, sendo que 2 cartões já estão inclusos.
#
# 2. **Autorização de Carga**: Após o cadastro, os cartões permitem a autorização de carga local.
#
# 3. **Gerenciamento de Cartões**: Você pode adicionar ou excluir cartões conforme necessário na plataforma de monitoramento.
#
# Certifique-se de seguir as instruções específicas da plataforma para realizar o cadastro e gerenciamento dos cartões RFID. (Fonte: User Manual V1.1-2024-10-12)
#
# [FONTES RECUPERADAS]
#    • Goodwe Hca Series User Manual.pdf p.59
#    • Apresentação Challenge FIAP4+GoodWe 2026.pdf p.12
#    • FIAP_EV Challenge_2026_Mentoria1.pdf p.5
#    • Goodwe Hca Series User Manual.pdf p.50
# ----------------------------------------------------------------------
#
# [PERGUNTA 5]
# >>> How to connect the charger to the SolarGo app for the first time?
#
# [RESPOSTA]
# Para conectar o carregador ao aplicativo SolarGo pela primeira vez, siga os passos abaixo:
#
# 1. **Certifique-se de que o carregador está ligado e funcionando corretamente.**
# 2. **Selecione a aba Bluetooth na página inicial do aplicativo SolarGo.**
# 3. **Atualize a lista de dispositivos** puxando para baixo ou tocando em "Search Device". Encontre o dispositivo pelo número de série do carregador e toque no nome do dispositivo para fazer login na página inicial.
# 4. **(Opcional)**: Para a primeira conexão com o equipamento via Bluetooth, haverá um prompt de emparelhamento Bluetooth. Toque em "Pair" para continuar a conexão.
# 5. **Digite a senha de login** para acessar a página inicial. A senha inicial é: **goodwe2022**.
# 6. **(Opcional)**: Se a senha inicial for utilizada, o aplicativo solicitará que você a altere após o login. Altere-a conforme suas necessidades.
#
# Essas instruções estão disponíveis no documento "User Manual V1.1-2024-10-12", seção 8.2.2.
#
# [FONTES RECUPERADAS]
#    • Goodwe Hca Series User Manual.pdf p.43
#    • GW_HCA Series_User Manual-EN.pdf p.13
#    • Goodwe Hca Series User Manual.pdf p.7
#    • Goodwe Hca Series User Manual.pdf p.42
# ----------------------------------------------------------------------

# %%
memory.clear()
print("GoodWe Chatbot — digite 'sair' para encerrar\n")

while True:
    question = input("Você: ").strip()
    if question.lower() == 'sair':
        print("Encerrando chat.")
        break
    if not question:
        continue

    response = chain.invoke({'question': question})
    print(f"\nBot: {response['answer']}")

    sources = response.get('source_documents', [])
    if sources:
        seen = set()
        for doc in sources:
            src = doc.metadata.get('source_file', '?')
            page = doc.metadata.get('page', '?')
            key = f'{src} p.{page}'
            if key not in seen:
                print(f'   📄 {key}')
                seen.add(key)
    print()
# Out:
# GoodWe Chatbot — digite 'sair' para encerrar
#
# Você: chat, me conte o que você sabe sobre o challenge da goodwe
#
# Bot: O EV Challenge 2026 da GoodWe é um evento que busca transformar dados em inteligência, energia em estratégia e ideias em soluções reais. O desafio é promovido pela GoodWe e está relacionado à mobilidade elétrica, com foco em orquestrar o futuro dessa área utilizando dados, IoT (Internet das Coisas) e inteligência artificial. A iniciativa é parte de um esforço para liderar o futuro da energia inteligente. Para mais informações, você pode consultar a comunidade GoodWe ou o material relacionado ao evento.
#    📄 Apresentação Challenge FIAP4+GoodWe 2026.pdf p.21
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.10
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.0
#    📄 Apresentação Challenge FIAP4+GoodWe 2026.pdf p.0
#
# Você: chat, os carregadores da linha HCA da goodwe tem suporte a sistemas de pagamento integrado?
#
# Bot: Os carregadores da linha HCA G2 da GoodWe não possuem um modelo padrão de cobrança e não oferecem suporte a plataformas terceiras de billing/pagamento. Portanto, não há suporte a sistemas de pagamento integrado para essa linha. Essa informação pode ser encontrada na seção "Pagamento e Modelo Comercial" do protocolo técnico.
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.5
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.7
#    📄 Apresentação Challenge FIAP4+GoodWe 2026.pdf p.12
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.4
#
# Você: e como podemos resolver esse problema?
#
# Bot: Para resolver o problema da ausência de um modelo padrão de cobrança e suporte a plataformas terceiras de billing/pagamento para a linha HCA G2 da GoodWe, algumas abordagens podem ser consideradas:
#
# 1. **Desenvolvimento de uma Plataforma de Billing Interna**: Criar um sistema de cobrança próprio que possa ser integrado aos carregadores HCA G2. Isso incluiria o desenvolvimento de um gateway de pagamento que permita a autenticação e liberação das recargas.
#
# 2. **Parcerias com Provedores de Pagamento**: Estabelecer parcerias com empresas que oferecem soluções de pagamento e billing, permitindo que os carregadores se conectem a essas plataformas de forma personalizada, mesmo que não haja suporte nativo.
#
# 3. **Modelo de Cobrança Flexível**: Implementar um modelo de cobrança que permita a divisão de receita entre os usuários e o condomínio, facilitando a gestão dos custos de energia e a cobrança automática por unidade habitacional.
#
# 4. **Gerenciamento Inteligente de Demanda**: Integrar um sistema de gerenciamento que otimize a demanda de potência e permita a cobrança baseada no consumo individual, garantindo que cada unidade habitacional pague apenas pelo que consome.
#
# 5. **Interface de Usuário**: Desenvolver uma interface amigável para os usuários e para a gestão do condomínio, permitindo que os usuários visualizem seu consumo e realizem pagamentos de forma simples e eficiente.
#
# Essas soluções devem ser abordadas considerando a arquitetura funcional, o papel da inteligência artificial, a viabilidade operacional e comercial, e a lógica da solução proposta, conforme indicado no escopo do desafio.
#    📄 Apresentação Challenge FIAP4+GoodWe 2026.pdf p.15
#    📄 Apresentação Challenge FIAP4+GoodWe 2026.pdf p.13
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.7
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.8
#
# Você: resuma essa resposta
#
# Bot: Um resumo das possíveis soluções para resolver a ausência de um modelo padrão de cobrança nos carregadores HCA G2 da GoodWe inclui:
#
# 1. **Desenvolvimento de uma Plataforma de Billing Interna**: Criar um sistema de cobrança próprio que integre um gateway de pagamento para autenticação e liberação das recargas.
#
# 2. **Parcerias com Provedores de Pagamento**: Estabelecer colaborações com empresas que oferecem soluções de pagamento, permitindo a conexão personalizada com as plataformas de billing.
#
# 3. **Modelo de Cobrança Flexível**: Implementar um modelo que possibilite a divisão de receita entre usuários e condomínios, facilitando a gestão dos custos de energia.
#
# 4. **Gerenciamento Inteligente de Demanda**: Integrar um sistema que otimize a demanda de potência e permita a cobrança baseada no consumo individual.
#
# 5. **Interface de Usuário**: Desenvolver uma interface amigável para que os usuários visualizem seu consumo e realizem pagamentos de forma eficiente.
#
# Essas soluções devem ser abordadas considerando a viabilidade técnica e comercial, conforme indicado no escopo do desafio.
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.7
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.5
#    📄 FIAP_EV Challenge_2026_Mentoria1.pdf p.6
#    📄 GW_HCA-G2_Datasheet-EN.pdf p.0
#
# Você: sair
# Encerrando chat.
